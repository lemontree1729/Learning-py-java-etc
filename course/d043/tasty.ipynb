# %%
import pandas as pd
dague = pd.read_csv('daeguPrice.csv', encoding = 'cp949')
dague

# %%
dague['구군'] == '동구'

# %%
dague[dague['구군'] == '동구'].sort_values(by="대표메뉴1 가격")

# %%
import json
with open('tasty.json', 'rt', encoding='UTF8') as json_file:
    json_data = json.load(json_file)
result = pd.json_normalize(json_data, "data")
result

# %%
result.loc[:, ['BZ_NM', 'FD_CS', 'GNG_CS', 'TLNO', 'MBZ_HR','BKN_YN', 'MNU', 'SMPL_DESC']].sort_values(by="GNG_CS")

# %%
with open('tasty2.json', 'rt', encoding='UTF8') as json_file2:
    json_data2 = json.load(json_file2)
result2 = pd.json_normalize(json_data2, "data")
result2.loc[result2['GNG_CS'].str.contains('불로동|봉무동|지묘동'), ['BZ_NM', 'FD_CS', 'GNG_CS', 'TLNO', 'MBZ_HR','BKN_YN', 'MNU', 'SMPL_DESC']].sort_values(by="GNG_CS")
# Out:
#            BZ_NM  FD_CS               GNG_CS          TLNO         MBZ_HR  \
# 118        왕산손짜장     중식   대구광역시 동구 봉무동 147-1  053-984-1344  10:00 ~ 21:00
# 30           자미성     중식  대구광역시 동구 봉무동 1543-3  053-986-8585  11:00 ~ 21:00
# 34            개정     한식  대구광역시 동구 봉무동 1543-5  053-982-3800  11:20 ~ 21:30
# 33      뜨삽(이시아점)     양식    대구광역시 동구 봉무동 1545  053-945-2576  11:00 ~ 21:00
# 49   풀잎채 이시아폴리스점  퓨전/뷔페    대구광역시 동구 봉무동 1545  053-945-2717  11:00 ~ 21:00
# 86           만수정     한식   대구광역시 동구 봉무동 362-3  053-985-1814    09:00~21:00
# 65        팔도웰빙쌈밥     한식  대구광역시 동구 불로동 1157-3  053-985-0124  11:00 ~ 22:00
# 66          달빛식당     한식    대구광역시 동구 불로동 1180  053-983-0202  11:00 ~ 22:00
# 128          기와집     한식   대구광역시 동구 불로동 210-1  053-981-0364  09:30 ~ 21:30
# 67         기와집한우     한식   대구광역시 동구 불로동 598-9  053-982-4488  10:00 ~ 22:00
# 38           명산가     한식   대구광역시 동구 불로동 965-1  053-984-3550  11:00 ~ 21:00
# 119      팔공참한우마실     한식   대구광역시 동구 지묘동 228-1  053-982-3382  10:00 ~ 22:00
#
#     BKN_YN                                                MNU  \
# 118     가능  짜장면 5,000원 <br />짬뽕 6,000원 <br />간짜장 6,000원 <b...
# 30      가능  궈바로 미니 13,000원 <br />오룡해삼 65,000원<br />전가복 75,...
# 34      가능  냉면(물냉/비냉) 10,000원 <br />전주비빔밥 11,000원 <br />전주...
# 33      가능  콰트로 포르마지 19,900원<br />고르곤졸라 17,900원<br />디아볼라 ...
# 49      가능  평일성인 14,900 취학 9,900 미취학 6,900<br />주말성인 18,90...
# 86      가능  전복탕 18,000원 <br />장어탕 18,000원 <br />얼큰장어탕 18,0...
# 65      가능  쌈밥정식(2인이상) 9,000원 <br />제육쌈밥(2인이상) 10,000원 <br...
# 66      가능  가오리찜 31000원 ~ 36,000원 <br />아구찜 24,000원 ~ 31,0...
# 128     가능  한정식 10,000원<br />삼계탕(2인이상) 10,000원<br />갈치찌개(2...
# 67      가능  한우모듬스페결(100g) 11,900원<br /> LA갈비(1.2kg) 39,800...
# 38      가능  [채식 메뉴 주문가능 - 섬나물비빔밥, 곤드레밥, 연잎밥 등]<br /><br />...
# 119     가능  갈비살(120g) 22,000원 <br />꽃등심(120g) 22,000원 <br ...
#
#                                              SMPL_DESC
# 118  구수한 전통 짜장면의 맛을 느끼고자 하는 손님들이 한번 드신 후 그 맛을 잊을수 없...
# 30   30년 이상 경력의 주방장과 오너 셰프가 조리하는 중국요리의 특별한 맛을 느낄 수 ...
# 34   대구에서 한식으로 명성을 떨치고 있는 개정은 전주비빔밥, 돌솥밥, 함흥식 냉면 등이...
# 33   [뜨삽]만의 화덕을 굽는 기술력을 바탕으로 최고의 도우와 치즈의 맛을 찾아내어 제공...
# 49   국내 한식 프리미엄 뷔페 최초브랜드. 제철먹거리 중심의 뷔페로 이시아폴리스 롯데아울...
# 86                      만수정은 장어가 통째로 들어가는 장어탕 전문점입니다.
# 65   팔도웰빙쌈밥은 쌈밥 전문점으로 집에서 쉽게 먹을 수 없는 다양한 종류의 제철 채소를...
# 66   찜요리 전문점인 달빛식당은 아구찜, 가오리찜, 코다리찜 등 다양한 종류의 찜요리를 ...
# 128                        기와집은 한정식과 삼계탕 등 한식 전문점입니다.
# 67   저렴한 가격으로 1+ 등급의 한우를 맛볼 수 있는 곳. 한우와 불고기, LA갈비, ...
# 38   산야초 발효음식 연구가 장선숙 오너 셰프가 직접 조리하는 곳으로 자연을 담은 건강한...
# 119  농장직영의 순수 한우 최고등급인 A1++ 만을 사용하기 때문에 육질이 부드럽고 고소...
