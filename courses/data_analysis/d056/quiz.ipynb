# %%
import pandas as pd
import matplotlib.pyplot as plt
from os import getcwd
print(getcwd())
# Out:
# d:\github\coding-academy\courses\data_analysis\d056

# %%
drink = pd.read_csv("../../../../data/drinks.csv")
drink.to_csv("../../../../data/drinks_bigdata.csv")
drink.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
p = drink.plot("country", "total_litres_of_pure_alcohol")
import matplotlib.font_manager as fm
from matplotlib import rc
font_path = "C:\\Windows\\Fonts\\Along.ttf"
font = fm.FontProperties(fname=font_path).get_name()
rc('font', family=font)
p.set_xlabel("나라", size=18)
p.set_ylabel("알코올도수", size=18)
# Out:
# Text(0, 0.5, '알코올도수')
