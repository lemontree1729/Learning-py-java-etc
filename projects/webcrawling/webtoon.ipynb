# %%
from crawling import *
from ploturl import *

# %%
webtoon = html_parser("https://comic.naver.com/webtoon/weekday", dynamic=False)
target = webtoon.select(".thumb>a")
data = set()
for i in target:
    data.add("https://comic.naver.com" + i.attrs["href"])
print(len(data))
cnt = 0
for i in data:
    if cnt == 3:
        break
    cnt+= 1
    print(i)
    plot_url(i)
# Out:
# 510
# https://comic.naver.com/webtoon/list?titleId=784129&weekday=sun
# https://comic.naver.com/webtoon/list?titleId=770015&weekday=thu
# https://comic.naver.com/webtoon/list?titleId=770477&weekday=tue
